# %%
import pandas as pd
import matplotlib as plt

# %% [markdown]
# ## Valutazione del tempo medio di risposta al variare della dimensione dei Batch

# %%
dati = {
            'K' : ['64','64','64','64','64','64','64','64'],
           'B': ['0','64', '128', '256', '512','1024','2048','4096'],
           'wait': [45.561089,29.634315,29.561872,30.898281 ,30.175526,  31.219218,32.082667,31.955978  ],
           'somma': [ 45.561089 + 9.604199,29.634315 + 3.595397,29.561872 + 3.036612,30.898281 + 2.195099,30.175526 + 1.699956, 31.219218 + 1.375955,32.082667 + 1.781379,31.955978 + 1.005845],
           'sottrazione': [ 45.561089 - 9.604199,29.634315 - 3.595397,29.561872 - 3.036612,30.898281 - 2.195099,30.175526 - 1.699956, 31.219218 - 1.375955,32.082667 - 1.781379,31.955978 - 1.005845],
           'autocorrelazione' : [0.3,0.6,0.3,0.1,0.0,0.0,0.1,0.1]}


df=pd.DataFrame(dati, columns=['K','B','wait', 'somma','sottrazione', 'autocorrelazione'])

# %%
import matplotlib.pyplot as plt
x=df.B

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(20, 9))
plt.gca().set_prop_cycle(color=colors)
plt.plot(x,df.wait,"o--",label="Tempo medio di risposta",linewidth=2.5)
plt.plot(x,df.somma,label="Limite superiore",linewidth=2.5)
plt.plot(x,df.sottrazione,label="Limite inferiore", color='b',linewidth=2.5)

plt.axhline(y=31.880974, color='g', linestyle='-')
plt.title("Tempo di risposta centro vaccinale con k = 64",fontsize=30)
plt.xlabel("B",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
# # Grafico autocorrelazione k = 64

# %%
import matplotlib.pyplot as plt
x=df.B

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(20, 9))
plt.gca().set_prop_cycle(color=colors)
plt.plot(x,df.autocorrelazione,"o--",label="Autocorrelazione",linewidth=2.5)


plt.axhline(y=0.2, color='g', linestyle='-')
plt.title("Autocorrelazione per k = 64",fontsize=30)
plt.xlabel("B",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 12)

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.5.0

# %%
import pandas as pd
from matplotlib.pyplot import figure
dati128 = {
            'K' : ['128','128','128','128','128','128','128','128'],
           'B': ['0','64', '128', '256', '512','1024','2048','4096'],
           'wait': [52.782588 ,29.561872, 30.898281 , 30.175526,31.219218,32.082667 ,31.955978,31.984170   ],
           'somma': [52.782588 + 7.727845,29.561872 +2.341666, 30.898281 + 2.079748, 30.175526 + 1.524814,31.219218 + 1.358889,32.082667 + 1.652740,31.955978 + 1.069005,31.984170 + 0.738099],
           'sottrazione': [52.782588 - 7.727845,29.561872 - 2.341666, 30.898281 - 2.079748 , 30.175526 - 1.524814,31.219218 - 1.358889,32.082667 - 1.652740,31.955978 - 1.069005,31.984170 - 0.738099],
           'autocorrelazione': [0.2,0.6,0.3, 0.1,0.1,0.3,0.1,0.0]}


df128=pd.DataFrame(dati128, columns=['K','B','wait', 'somma','sottrazione','autocorrelazione'])

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
x=df128.B

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(20, 9))
plt.gca().set_prop_cycle(color=colors)
plt.plot(x,df128.wait,"o--",label="Tempo di risposta del sistema",linewidth=2.5)
plt.plot(x,df128.somma,label="Limite superiore",linewidth=2.5)
plt.plot(x,df128.sottrazione,label="Limite inferiore", color='b',linewidth=2.5)

plt.axhline(y=31.880974, color='g', linestyle='-')
plt.title("Tempo di risposta centro vaccinale con k = 128",fontsize=30)
plt.xlabel("B",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
# # Grafico autocorrelazione per k = 128

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
x=df128.B

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(20, 9))
plt.gca().set_prop_cycle(color=colors)
plt.plot(x,df128.autocorrelazione,"o--",label="Autocorrelazione",linewidth=2.5)


plt.axhline(y=0.2, color='g', linestyle='-')
plt.title("Autocorrelazione per k = 128",fontsize=30)
plt.xlabel("B",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 12)
plt.show()

# %%
dati256 = {
            'K' : ['256','256','256','256','256','256','256','256'],
           'B': ['0','64', '128', '256', '512','1024','2048','4096'],
           'wait': [44.920410 , 28.832612,30.098760, 30.474565, 30.703029, 31.497895 , 31.488380 , 31.524063  ],
           'somma': [44.920410 + 4.605741,28.832612 + 1.574594, 30.098760 + 1.473844, 30.474565 + 1.331675, 30.703029 + 1.149852, 31.497895 + 1.041265, 31.488380 + 0.826535, 31.524063 + 0.610372],
           'sottrazione': [ 44.920410 - 4.605741,28.832612 - 1.574594, 30.098760 - 1.473844, 30.474565 - 1.331675, 30.703029 - 1.149852, 31.497895 - 1.041265, 31.488380 - 0.826535, 31.524063 - 0.610372],
           'autocorrelazione': [0.2,0.5, 0.3,0.1, 0.2, 0.1, 0.1, 0.2 ]}


df256=pd.DataFrame(dati256, columns=['K','B','wait', 'somma','sottrazione', 'autocorrelazione'])

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
x=df256.B

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(20, 9))
plt.gca().set_prop_cycle(color=colors)
plt.plot(x,df256.wait,"o--",label="Tempo di risposta del sistema",linewidth=2.5)
plt.plot(x,df256.somma,label="Limite superiore",linewidth=2.5)
plt.plot(x,df256.sottrazione,label="Limite inferiore", color='b',linewidth=2.5)

plt.axhline(y=31.642502, color='g', linestyle='-')
plt.title("Tempo di risposta centro vaccinale con k = 256",fontsize=30)
plt.xlabel("B",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
# # Grafico autocorrelazione per k = 256

# %%
import matplotlib.pyplot as plt
x=df256.B

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(20, 9))
plt.gca().set_prop_cycle(color=colors)
plt.plot(x,df256.autocorrelazione,"o--",label="Autocorrelazione",linewidth=2.5)


plt.axhline(y=0.2, color='g', linestyle='-')
plt.title("Autocorrelazione per k = 256",fontsize=30)
plt.xlabel("B",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 12)

# %% [markdown]
# # Tempo medio di risposta al variare di K

# %%
datiris = {
            'K' : ['0','60','120','180','240'],
           'wait': [29.634315,32.014412 ,31.901711 ,31.802548, 31.947876 ]}


dfris=pd.DataFrame(datiris, columns=['K','B','wait', 'somma','sottrazione'])

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
x=dfris.K

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(20, 9))
plt.gca().set_prop_cycle(color=colors)
plt.plot(x,dfris.wait,"o--",label="Tempo medio di risposta simulato",linewidth=2.5)

plt.axhline(y=25, color='r', linestyle='-', label ="QoS")
plt.axhline(y=31.880974, color='g', linestyle='-', label ="Tempo medio di risposta teorico")
plt.title("Valutazione Qos del sistema per la configurazione {1,2,2,2}",fontsize=30)
plt.xlabel("B",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
# ## QoS Sistema senza modificare la configurazione

# %%
dati_qos = {
            'sistema' : ['sistema'],
           'wait': [31.955978]}
df_qos=pd.DataFrame(dati_qos, columns=['wait','sistema'])

# %%
df_qos
# Out:
#         wait  sistema
# 0  31.497895  sistema

# %%
x = df_qos.sistema

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(25, 16))
plt.gca().set_prop_cycle(color=colors)
plt.scatter(x,df_qos.wait,marker = "o",label="Tempo di risposta ottenuto", color = 'red', s = 200)


plt.axhline(y=25.00, color='green', linestyle='-', label = 'QoS', linewidth=2.5)
plt.title("QoS centro vaccinale {1,2,2,2}",fontsize=30)
plt.xlabel("",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# ## Confronto al variare dei tassi Accettazione (Validazione)

# %%
ac_tassi = {
            'tasso' : ['accettazione'],
           'wait': [33.443680 ]
           
           
            }
ac_tassi_df=pd.DataFrame(ac_tassi, columns=['wait','tasso'])

# %%
x = ac_tassi_df.tasso
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(25, 16))
plt.gca().set_prop_cycle(color=colors)
plt.scatter(x,ac_tassi_df.wait,marker = "o",label="Lambda = 0.483 job/min",s = 200 ,color='r')



plt.axhline(y=17.136825, color='b', linestyle='-', linewidth=2.5, label = 'Lambda = 0.456 job/min')
plt.title("Test coerenza Accettazione",fontsize=30)
plt.xlabel("",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# ## Confronto al variare dei tassi Anamnesi (Validazione)

# %%
an_tassi = {
            'tasso' : ['anamnesi'],
           'wait': [9.395655 ]

            }
an_tassi_df=pd.DataFrame(an_tassi, columns=['wait','tasso'])

# %%
x = an_tassi_df.tasso
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(25, 16))
plt.gca().set_prop_cycle(color=colors)
plt.scatter(x,an_tassi_df.wait,marker = "o",label="Lambda = 0.483 job/min",linewidth=2.5 ,color='r', s = 200)



plt.axhline(y=7.826133, color='b', linestyle='-',linewidth=2.5, label = 'Lambda = 0.456 job/min')
plt.title("Test coerenza Anamnesi",fontsize=30)
plt.xlabel("",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# ## Confronto al variare dei tassi Inoculazione (Validazione)

# %%
in_tassi = {
            'tasso' : ['Inoculazione'],
           'wait': [9.640415 ]
            }
in_tassi_df=pd.DataFrame(in_tassi, columns=['wait','tasso'])

# %%
x = in_tassi_df.tasso
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(25, 16))
plt.gca().set_prop_cycle(color=colors)
plt.scatter(x,in_tassi_df.wait,marker = "o",label="Lambda = 0.483 job/min",linewidth=2.5 ,color='r', s = 200)



plt.axhline(y=8.160273, color='b', linestyle='-', linewidth=2.5 , label = 'Lambda = 0.456 job/min')
plt.title("Test coerenza Inoculazione",fontsize=30)
plt.xlabel("",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# ## Confronto al variare dei tassi Inoculazione Attenuato (Validazione)

# %%
att_tassi = {
            'tasso' : ['Inoculazione Attenuato'],
           'wait': [2.836611 ]

            }
att_tassi_df=pd.DataFrame(att_tassi, columns=['wait','tasso'])

# %%
x = att_tassi_df.tasso
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(25, 16))
plt.gca().set_prop_cycle(color=colors)
plt.scatter(x,att_tassi_df.wait,marker = "o",label="Lambda = 0.483 job/min",linewidth=2.5 ,color='r', s = 200)

2.842897

plt.axhline(y= 2.829814,color='b', linestyle='-', label = 'Lambda = 0.456 job/min', linewidth=2.5)
plt.title("Test coerenza Inoculazione Attenuato",fontsize=30)
plt.xlabel("",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# ## Confronto con l'aumento dei server nel centro anamnesi (Validazione)

# %%
an_server = {
            'tasso' : ['anamnesi'],
           'wait': [3.862445 ]
           
           
            }
an_server_df=pd.DataFrame(an_server, columns=['wait','tasso','somma','sottrazione'])

# %%
x = an_server_df.tasso
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(25, 16))
plt.gca().set_prop_cycle(color=colors)
plt.scatter(x,an_server_df.wait,marker = "o",label="3 Server",linewidth=2.5 ,color='r', s = 200)



plt.axhline(y=7.826133, color='b', linestyle='-',linewidth=2.5 , label = '2 Server')
plt.title("Test coerenza sui server per il centro di Anamnesi",fontsize=30)
plt.xlabel("",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# ## QoS centro vaccinale {1,3,2,2}

# %%
dati_qos_new = {
            'sistema' : ['sistema'],
           'wait': [27.552782  ]}
df_qos_new=pd.DataFrame(dati_qos_new, columns=['wait','sistema'])

# %%
x = df_qos_new.sistema

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(25, 16))
plt.gca().set_prop_cycle(color=colors)
plt.scatter(x,df_qos_new.wait,marker = "o",label="Tempo di risposta del sistema",linewidth=2.5, color = 'red', s = 200)


plt.axhline(y=25.00, color='green', linestyle='-', linewidth=2.5 , label = 'QoS')
plt.title("QoS centro vaccinale configurazione {1,3,2,2}",fontsize=30)
plt.xlabel("",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# ## Qos sistema {1,3,3,2}

# %%
dati_qos_new2 = {
            'sistema' : ['sistema'],
           'wait': [24.975333  ]}
df_qos_new2=pd.DataFrame(dati_qos_new2, columns=['wait','sistema'])

# %%
x = df_qos_new2.sistema

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(25, 16))
plt.gca().set_prop_cycle(color=colors)
plt.scatter(x,df_qos_new2.wait,marker = "o",label="Tempo di risposta del sistema",linewidth=2.5, color = 'red', s = 200)


plt.axhline(y=25.00, color='green', linestyle='-', linewidth=2.5, label = 'QoS')
plt.title("QoS centro vaccinale configurazione {1,3,3,2}",fontsize=30)
plt.xlabel("",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# # Valutazione QoS configurazione {1,3,3,2}

# %%
datiris2 = {
            'K' : ['0','60','120','180','240'],
           'wait': [ 19.485149, 24.223692  ,24.868083 ,24.984038,24.998514 ]}


dfris2=pd.DataFrame(datiris2, columns=['K','B','wait', 'somma','sottrazione'])

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
x=dfris2.K

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(20, 9))
plt.gca().set_prop_cycle(color=colors)
plt.plot(x,dfris2.wait,"o--",label="Tempo medio di risposta simulato",linewidth=2.5)

plt.axhline(y=25, color='r', linestyle='-', label ="QoS")
plt.axhline(y=24.847579, color='g', linestyle='-', label ="Tempo medio di risposta teorico")
plt.title("Valutazione QoS per la configurazione {1,3,3,2}",fontsize=30)
plt.xlabel("B",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
# ## QoS orizzonte finito {1,3,3,2}

# %%
dati_qos_finito1 = {
            
            'time' : ['0','60','120','180','240','300','360'],
           'wait': [0,19.080376,20.847592,21.240110,21.335309,21.750929,21.627248]}
           
df_qos_finito1=pd.DataFrame(dati_qos_finito1, columns=['wait','sistema','time','somma','sottrazione'])

# %%
x = df_qos_finito1.time

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(25, 16))
plt.gca().set_prop_cycle(color=colors)
plt.plot(x,df_qos_finito1.wait,label="Tempo di risposta del sistema",linewidth=2.5, color = 'g')
plt.plot(x,df_qos_finito1.somma,label="Tempo di risposta del sistema",linewidth=2.5, color = 'red')
plt.plot(x,df_qos_finito1.sottrazione,label="Tempo di risposta del sistema",linewidth=2.5, color = 'b')


plt.axhline(y=25.00, color='r', linestyle='-', linewidth=2.5, label = 'QoS')
plt.title("Simulazione ad orizzonte finito con la configurazione {1,3,3,2}",fontsize=30)
plt.xlabel("time",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 20)
plt.show()

# %%
dati_qos_finito = {
            'sistema' : ['sistema'],
           'wait': [18.785032   ]}
df_qos_finito=pd.DataFrame(dati_qos_finito, columns=['wait','sistema'])

# %%
x = df_qos_finito.sistema

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(25, 16))
plt.gca().set_prop_cycle(color=colors)
plt.scatter(x,df_qos_finito.wait,marker = "o",label="Tempo di risposta del sistema",linewidth=2.5, color = 'red', s = 200)


plt.axhline(y=25.00, color='green', linestyle='-',  label = 'QoS',linewidth=2.5)
plt.title("QoS centro vaccinale simulazione ad orizzonte finito",fontsize=30)
plt.xlabel("",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# ## Sistema migliorato

# %%
dati_qos_mig = {
            'sistema' : ['sistema'],
           'wait': [17.420526  ] }
df_qos_mig=pd.DataFrame(dati_qos_mig, columns=['wait','sistema'])

# %%
x = df_qos_mig.sistema

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(25, 16))
plt.gca().set_prop_cycle(color=colors)
plt.scatter(x,df_qos_mig.wait,marker = "o",label="Tempo di risposta del sistema",linewidth=2.5, color = 'red', s = 200)


plt.axhline(y=25.00, color='green', linestyle='-', linewidth=2.5, label = 'Qos')
plt.title("QoS centro vaccinale modello migliorativo",fontsize=30)
plt.xlabel("",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# # QoS centro vaccinale simulazione ad orizzonte finito

# %%
dati_qos_mig_fin = {
            'sistema' : ['sistema'],
           'wait': [15.913649  ] }
df_qos_mig_fin=pd.DataFrame(dati_qos_mig_fin, columns=['wait','sistema'])

# %%
x = df_qos_mig_fin.sistema

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(25, 16))
plt.gca().set_prop_cycle(color=colors)
plt.scatter(x,df_qos_mig_fin.wait,marker = "o",label="Tempo di Risposta del sistema",linewidth=2.5, color = 'red', s = 200)


plt.axhline(y=25.00, color='green', linestyle='-',linewidth=2.5,label = 'QoS')
plt.title("QoS centro vaccinale modello migliorativo orizzonte finito",fontsize=30)
plt.xlabel("",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# # Confronto Modelli

# %%
dati_confronto = {
            'name' : ['modello iniziale', 'modello migliorativo'],
           'wait': [24.975333 , 17.420526]}
           
df_confronto=pd.DataFrame(dati_confronto, columns=['name','wait'])

# %%
df_confronto
# Out:
#                    name       wait
# 0      modello iniziale  24.636665
# 1  modello migliorativo  17.231323

# %%
import matplotlib
from matplotlib.pyplot import figure

# %%
figure(figsize=(16, 9), dpi=80)
matplotlib.pyplot.bar(df_confronto.name, height=df_confronto.wait, width=0.8, bottom=None,  align='center', data=df_confronto.wait, color=['r', 'g'])

plt.title("Confronto tempo di risposta dei modelli",fontsize=30)
# Out:
# Text(0.5, 1.0, 'Confronto tempo di risposta dei modelli')

# %% [markdown]
# # Sistema migliorato configurazione ottima convergenza

# %%
datimig = {
            'K' : ['0','60','120','180','240','300'],
           'wait': [ 15.970928,17.263502,17.439758,17.500611,17.499976,17.563162]}


dfmig=pd.DataFrame(datimig, columns=['K','B','wait', 'somma','sottrazione'])

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
x=dfmig.K

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=['orange', 'purple', 'green','red']
plt.figure(figsize=(20, 9))
plt.gca().set_prop_cycle(color=colors)
plt.plot(x,dfmig.wait,"o--",label="Tempo medio di risposta simulato",linewidth=2.5)

plt.axhline(y=25, color='r', linestyle='-', label ="QoS")
plt.axhline(y=17.568479, color='g', linestyle='-', label ="Tempo medio di risposta teorico")
plt.title("Valutazione QoS per la configurazione {1,2,2,1} del sistema migliorato",fontsize=30)
plt.xlabel("batch",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
# # QoS sistema migliorato orizzonte finito

# %%
dati_qos_finito_mig = {
            
            'time' : ['0','60','120','180','240','300','360'],
           'wait': [0,14.800121,15.422104,16.215137,15.850758,16.512028,16.973091 ]}
df_qos_finito_mig=pd.DataFrame(dati_qos_finito_mig, columns=['wait','sistema','time'])

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
x=df_qos_finito_mig.time

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=[ 'purple', 'green','red']
plt.figure(figsize=(20, 9))
plt.gca().set_prop_cycle(color=colors)
plt.plot(x,df_qos_finito_mig.wait,"o--",label="Tempo medio di risposta ",linewidth=1.5)
plt.axhline(y=25, color='r', linestyle='-', label ="QoS")
plt.title("QoS centro vaccinale modello migliorativo orizzonte finito",fontsize=30)
plt.xlabel("time",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 12)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
x=df_qos_finito_mig.time

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=[ 'purple', 'green','red']
plt.figure(figsize=(20, 9))
plt.gca().set_prop_cycle(color=colors)
plt.plot(x,df_qos_finito1.wait,"o--",label="Tempo medio di risposta sistema ",linewidth=1.5)
plt.plot(x,df_qos_finito_mig.wait,"o--",label="Tempo medio di risposta sistema migliorato ",linewidth=1.5)
plt.axhline(y=25, color='r', linestyle='-', label ="QoS")
plt.title("Confronto tra i due modelli",fontsize=30)
plt.xlabel("time",fontsize=20)
plt.ylabel("Wait",fontsize=20)
plt.legend(fontsize = 12)
plt.show()

# %%
pazienti_accettazione = {
            
            'batch' : ['0','60','120','180','240'],
           'job': [5.209652,7.737159,7.688053,7.736467, 7.747820]}
df_pazienti_accettazione=pd.DataFrame(pazienti_accettazione, columns=['job','sistema','batch'])

pazienti_anamnesi = {
            
            'batch' : ['0','60','120','180','240'],
           'job': [ 1.734182,1.762117,1.759892,1.761876,1.766793]}
df_pazienti_anamnesi=pd.DataFrame(pazienti_anamnesi, columns=['job','sistema','batch'])

pazienti_inoculazione = {
            
            'batch' : ['0','60','120','180','240'],
           'job': [1.590548, 1.632799 ,1.630542,1.630781,1.629126]}
df_pazienti_inoculazione=pd.DataFrame(pazienti_inoculazione, columns=['job','sistema','batch'])

pazienti_attenuato = {
            
            'batch' : ['0','60','120','180','240'],
           'job': [0.279604,0.282356,0.282319,0.282648,0.282504]}
df_pazienti_attenuato=pd.DataFrame(pazienti_attenuato, columns=['job','sistema','batch'])

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
x=df_pazienti_accettazione.batch

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=[ 'purple', 'green','red']
plt.figure(figsize=(20, 9))
plt.gca().set_prop_cycle(color=colors)
plt.plot(x,df_pazienti_accettazione.job,"o--",label="Numero medio di job in accettazione ",linewidth=1.5)
plt.plot(x,df_pazienti_anamnesi.job,"o--",label="Numero medio di job in anamnesi ",linewidth=1.5)
plt.plot(x,df_pazienti_inoculazione.job,"o--",label="Numero medio di job in inoculazione ",linewidth=1.5)
plt.plot(x,df_pazienti_attenuato.job,"o--",label="Numero medio di job in inoculazione attenuato ",linewidth=1.5)


plt.axhline(y=7.728813, color='purple', linestyle='-', label ="Numero medio di job nel centro valore teorico accettazione")
plt.axhline(y=1.694895, color='green', linestyle='-', label ="Numero medio di job nel centro valore teorico anamnesi")
plt.axhline(y=1.682892, color='red', linestyle='-', label ="Numero medio di job nel centro valore teorico inoculazione")
plt.axhline(y=0.282811, color='orange', linestyle='-', label ="Numero medio di job nel centro valore teorico attenuato")

plt.title("Numero di job",fontsize=30)
plt.xlabel("batch",fontsize=20)
plt.ylabel("job",fontsize=20)
plt.legend(fontsize = 12)
plt.show()

# %%
pazienti_accettazione = {
            
            'batch' : ['0','60','120','180','240','300','360'],
           'time': [0,10.802392,12.645599,13.317973,13.312234,13.800426,13.666173]}
df_pazienti_accettazione=pd.DataFrame(pazienti_accettazione, columns=['time','sistema','batch'])

pazienti_anamnesi = {
            
            'batch' : ['0','60','120','180','240','300','360'],
           'time': [ 0,3.716661,3.738867,3.739122,3.769712,3.743608,3.805728]}
df_pazienti_anamnesi=pd.DataFrame(pazienti_anamnesi, columns=['job','sistema','time'])

pazienti_inoculazione = {
            
            'batch' : ['0','60','120','180','240','300','360'],
           'time': [0,4.455908,4.513333,4.523385,4.481992,4.524897,4.573123]}
df_pazienti_inoculazione=pd.DataFrame(pazienti_inoculazione, columns=['job','sistema','time'])

pazienti_attenuato = {
            
            'batch' : ['0','60','120','180','240','300','360'],
           'time': [0,2.771573,2.812971,2.775795,2.855902,2.857322,2.801199]}
df_pazienti_attenuato=pd.DataFrame(pazienti_attenuato, columns=['job','sistema','time'])

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
x=df_pazienti_accettazione.batch

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=[ 'purple', 'green','red','orange']
plt.figure(figsize=(20, 9))
plt.gca().set_prop_cycle(color=colors)
plt.plot(x,df_pazienti_accettazione.time,"o--",label="Tempo di risposta accettazione ",linewidth=1.5)
plt.plot(x,df_pazienti_anamnesi.time,"o--",label="Tempo di risposta anamnesi",linewidth=1.5)
plt.plot(x,df_pazienti_inoculazione.time,"o--",label="Tempo di risposta inoculazione",linewidth=1.5)
plt.plot(x,df_pazienti_attenuato.time,"o--",label="Tempo di risposta inoculazione attenuato ",linewidth=1.5)



plt.title("Tempo di risposta dei centri {1,3,3,2}",fontsize=30)
plt.xlabel("time",fontsize=20)
plt.ylabel("wait",fontsize=20)
plt.legend(fontsize = 12)
plt.show()

# %%
pazienti_accettazione = {
            
            'batch' : ['0','60','120','180','240','300','360'],
           'time': [0,2.328237,2.388799,2.387773,2.385244,2.393603,2.410530]}
df_pazienti_accettazione=pd.DataFrame(pazienti_accettazione, columns=['time','sistema','batch'])

pazienti_anamnesi = {
            
            'batch' : ['0','60','120','180','240','300','360'],
           'time': [ 0,6.356589,6.710853, 7.161845,7.098242,7.307021,7.272450]}
df_pazienti_anamnesi=pd.DataFrame(pazienti_anamnesi, columns=['job','sistema','time'])

pazienti_inoculazione = {
            
            'batch' : ['0','60','120','180','240','300','360'],
           'time': [0,7.042413,7.321795,7.936321,7.893000,8.215693,8.201840]}
df_pazienti_inoculazione=pd.DataFrame(pazienti_inoculazione, columns=['job','sistema','time'])

pazienti_attenuato = {
            
            'batch' : ['0','60','120','180','240','300','360'],
           'time': [0,3.747004,3.651042,3.779576,3.782513,3.721695,3.794276]}
df_pazienti_attenuato=pd.DataFrame(pazienti_attenuato, columns=['job','sistema','time'])

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
x=df_pazienti_accettazione.batch

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
colors=[ 'purple', 'green','red','orange']
plt.figure(figsize=(20, 9))
plt.gca().set_prop_cycle(color=colors)
plt.plot(x,df_pazienti_accettazione.time,"o--",label="Tempo di risposta accettazione ",linewidth=1.5)
plt.plot(x,df_pazienti_anamnesi.time,"o--",label="Tempo di risposta anamnesi",linewidth=1.5)
plt.plot(x,df_pazienti_inoculazione.time,"o--",label="Tempo di risposta inoculazione",linewidth=1.5)
plt.plot(x,df_pazienti_attenuato.time,"o--",label="Tempo di risposta inoculazione attenuato ",linewidth=1.5)



plt.title("Tempo di risposta dei centri {2,2,2,1} Sistema migliorato",fontsize=30)
plt.xlabel("time",fontsize=20)
plt.ylabel("wait",fontsize=20)
plt.legend(fontsize = 12)
plt.show()

# %%
pazienti_accettazione = {
            
            'batch' : ['0','60','120','180','240','300'],
           'time': [0,2.240306,2.363903,2.252841,2.341243,2.329932]}
df_pazienti_accettazione=pd.DataFrame(pazienti_accettazione, columns=['time','sistema','batch'])

pazienti_anamnesi = {
            
            'batch' : ['0','60','120','180','240','300'],
           'time': [ 0,5.358814,6.727592,6.727946,6.799009,6.688727]}
df_pazienti_anamnesi=pd.DataFrame(pazienti_anamnesi, columns=['job','sistema','time'])

pazienti_inoculazione = {
            
            'batch' : ['0','60','120','180','240','300'],
           'time': [0,5.900548,6.497598,6.778045,6.774984,6.743300]}
df_pazienti_inoculazione=pd.DataFrame(pazienti_inoculazione, columns=['job','sistema','time'])

pazienti_attenuato = {
            
            'batch' : ['0','60','120','180','240','300'],
           'time': [0,3.000488,3.823238,3.649284,3.729303,3.720712]}
df_pazienti_attenuato=pd.DataFrame(pazienti_attenuato, columns=['job','sistema','time'])

# %% [markdown]
# ## Test coerenza accettazione

# %%
figure(figsize=(16, 9), dpi=80)
matplotlib.pyplot.bar(df_confronto.name, height=df_confronto.wait, width=0.8, bottom=None,  align='center', data=df_confronto.wait, color=['#DC143C', '#008080'])

plt.title("Confronto tempo di risposta dei modelli",fontsize=30)
# Out:
# Text(0.5, 1.0, 'Confronto tempo di risposta dei modelli')

# %%
import numpy as np
labels = ['Accettazione', 'Anamnesi', 'Inoculazione', 'Attenuato']
valori1 = [17.136825, 7.826133, 8.160273, 2.829814]
valori2 = [33.443680, 9.395655, 9.640415, 2.836611]



larghezza = 0.25

posizioni1 = np.arange(len(valori1))
posizioni2 = [x + larghezza for x in posizioni1]
posizioni3 = [x + larghezza for x in posizioni2]
figure(figsize=(16, 9), dpi=80)

plt.bar(posizioni1, valori1, larghezza, label='Tempo di risposta per Lambda = 0.456', color = '#008080')
plt.bar(posizioni2, valori2, larghezza, label='Tempo di risposta per Lambda = 0.483',color = '#DC143C')


plt.xticks([r + larghezza / 2 for r in range(len(valori2))], labels)

plt.legend()

plt.show()

# %%
import numpy as np
labels = ['Accettazione', 'Anamnesi', 'Inoculazione', 'Attenuato']
valori1 = [0.886354, 0.758221, 0.716565, 0.138441]
valori2 = [0.938444, 0.802242, 0.761391, 0.146388]



larghezza = 0.25

posizioni1 = np.arange(len(valori1))
posizioni2 = [x + larghezza for x in posizioni1]
posizioni3 = [x + larghezza for x in posizioni2]
figure(figsize=(16, 9), dpi=80)

plt.bar(posizioni1, valori1, larghezza, label='Utilizzazione per Lambda = 0.456', color = '#008080')
plt.bar(posizioni2, valori2, larghezza, label='Utilizzazione per Lambda = 0.483',color = '#DC143C')


plt.xticks([r + larghezza / 2 for r in range(len(valori2))], labels)


plt.legend()


plt.show()

# %%
import numpy as np
labels = ['Anamnesi']
valori1 = [7.826133]
valori2 = [3.862445]


# larghezza delle barre
larghezza = 0.25

# posizione delle barre sull'asse x
posizioni1 = np.arange(len(valori1))
posizioni2 = [x + larghezza for x in posizioni1]

figure(figsize=(16, 9), dpi=80)
# creazione del grafico a barre
plt.bar(posizioni1, valori1, larghezza, label='Tempo medio di risposta con 2 server', color = '#DC143C')
plt.bar(posizioni2, valori2, larghezza, label='Tempo medio di risposta con 3 server',color = '#008080')

# impostazione delle etichette sull'asse x
plt.xticks([r + larghezza / 2 for r in range(len(valori2))], labels)

# aggiunta della legenda
plt.legend()

# visualizzazione del grafico
plt.show()
